# %% [markdown]
# # Text Preprocessing

# %% [markdown]
# ## 1. Data Checking :

# %% [markdown]
# Melakukan pengecekan data, seperti nilai null dan memisahkan fitur yang akan digunakan.

# %%
import pandas as pd
df = pd.read_excel('data/ulasan_tiket_kai_access_labeling_reviewer.xlsx')
df['reviewer_1_sadam'] = df['reviewer_1_sadam'].replace({1:"Positive", 2: "Negative"})
df['reviewer_2_malik'] = df['reviewer_2_malik'].replace({1:"Positive", 2: "Negative"})
df['reviewer_3_dafit'] = df['reviewer_3_dafit'].replace({1:"Positive", 2: "Negative"})

df.rename(columns = {'reviewer_1_sadam':'reviewer1',
                     'reviewer_2_malik':'reviewer2',
                     'reviewer_3_dafit':'reviewer3'}, inplace=True
         )

print("total data: ", len(df))
df.head()
# Out:
# total data:  6000
#                                reviewId         userName  \
# 0  3248bbba-661b-405e-aaf8-25e13967c96f  Ulah Tri Wibowo
# 1  3d640dcf-1cf0-497e-8450-469e840b933e    aldilatama hs
# 2  fe7f8578-fc04-4532-8753-04358a52273f        dila asdf
# 3  92bf3440-9106-495f-ae4c-299c97315246    Retno Dumilah
# 4  aabf2156-6ccc-4079-bd8c-91c95faab830          Ajp cnl
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/AD_cM...
# 1  https://play-lh.googleusercontent.com/a-/AD_cM...
# 2  https://play-lh.googleusercontent.com/a-/AD_cM...
# 3  https://play-lh.googleusercontent.com/a/AAcHTt...
# 4  https://play-lh.googleusercontent.com/a-/AD_cM...
#
#                                              content  score  thumbsUpCount  \
# 0  Saya pertama kali coba aplikasi dan sangat kec...      1             12
# 1  app in sering bikin jantung berdebar-debar gar...      3              4
# 2  Bikin apk seperti niat tidak niat, saya udh da...      1             15
# 3  Pembatalan tiket sangat Dipersulit, tidak Flek...      2              5
# 4  KAI perusahaan besar dan bonafide, perombakan ...      2              5
#
#   reviewCreatedVersion                   at replyContent repliedAt appVersion  \
# 0                5.1.4  2023-06-16 18:19:11          NaN       NaN      5.1.4
# 1                5.1.4  2023-06-18 11:32:55          NaN       NaN      5.1.4
# 2                5.1.4  2023-06-10 14:20:19          NaN       NaN      5.1.4
# 3                5.1.4  2023-06-20 13:05:54          NaN       NaN      5.1.4
# 4                5.1.4  2023-06-22 13:15:43          NaN       NaN      5.1.4
#
#   reviewer1 reviewer2 reviewer3  total_negative  total_positive     label
# 0  Negative  Negative  Negative               3               0  Negative
# 1  Negative  Negative  Negative               3               0  Negative
# 2  Negative  Negative  Negative               3               0  Negative
# 3  Negative  Negative  Negative               3               0  Negative
# 4  Negative  Negative  Negative               3               0  Negative

# %%
# menghapus kolom selain content, at, reviewer, total positive, total negative, dan label
df.drop(df.columns[[0, 1, 2, 4, 5, 6, 8, 9, 10]], axis=1, inplace=True)

# %%
# cek hasil positive & negative berdasarkan review
df_filter_totaldiff = df[(df["total_negative"] == 1) & (df["total_positive"] == 2)]
df_filter_totaldiff.head(60).reset_index(drop=True)
# Out:
#                                               content                   at  \
# 0   Sangat membantu selama masih tersedia tempat d...  2023-03-07 12:25:14
# 1   Saldo baru isi tgl 2,, tp skrng knp eror ya,, ...  2023-02-08 01:12:38
# 2   Min, izin mau nanya kenapa pada saat saya ingi...  2023-02-18 11:04:03
# 3   Pelayanan nya bagus sangat membantu,hemat kert...  2019-11-26 14:21:28
# 4   Aplikasi sangat memudahkan pemesanan tiket 👍🏻👍...  2021-03-17 17:07:45
# 5   Aplikasi mudah di gunakan. Sayang agak loding ...  2023-02-08 04:32:50
# 6   Saya mengupdate app ini itu adalah peduli akan...  2022-09-12 18:06:56
# 7   Pesan tiket lebih mudah tapi metode pembayaran...  2023-04-29 09:46:07
# 8   Pliss KAI access 3 hari ini kenapa error, tolo...  2023-05-09 00:08:45
# 9   Kenapa kereta api antar kota yang berhenti di ...  2023-04-14 09:22:15
# 10  Sudah bagus dan mempermudah konsumen untuk mem...  2023-02-24 15:14:34
# 11  Terus tingkatkan lagi , kalo bisa pembayaran d...  2020-03-13 07:56:28
# 12  Aplikasi ini harus menggunakan smartphone andr...  2023-02-26 21:43:50
# 13  Ini kan aplikasi resmi PT KAI ya, seharusnya d...  2023-01-20 12:17:12
# 14  Saya kasih bintang 5 nih supaya di baca keluha...  2023-03-07 01:16:06
# 15  Bagus aplikasinya, tapi dulu, sebelum di insta...  2023-06-13 18:17:04
# 16  Sejauh ini pengalaman saya memakai apk ini san...  2023-05-06 05:14:27
# 17  Cara bayar yg cukup menyusahkan. TIDAK ADA men...  2021-06-06 08:20:58
# 18  Saya juga kesulitan membatalkan tiket yg di be...  2020-03-27 17:28:29
# 19  pakai kai access memang sangat praktis sekali ...  2019-09-01 09:43:22
# 20  Pemesanan tiket sebelum" nya sudah bagus dan s...  2019-09-06 12:54:10
# 21  Memudahkan sekali dalam pembelian tiket tidak ...  2022-09-29 06:26:19
# 22  Selama saya pake aplikasi ini, tidak ada kenda...  2020-03-10 12:58:34
# 23  Hai kak, saya pengguna kai acces sejak dulu. N...  2021-06-12 14:58:43
# 24  Aplikasi yg sangat Berguna banget, lebih efisi...  2023-01-11 18:05:02
# 25  Pemesanan tiket sangat mudah sekali, tidak sep...  2023-03-19 13:05:57
# 26  Membeli tiket untuk Ka lokal hanya bisa dibaya...  2019-04-17 15:59:30
# 27  Sungguh mantabs suka error sekarang, susah bua...  2022-06-17 01:59:58
# 28  Saya sudah dapat tiket. Pas mau bayar tapi gag...  2023-03-17 06:09:40
# 29  Aplikasi sangat membantu, jadi tidak perlu lag...  2019-11-01 14:27:14
# 30  Bagus aplikasinya dan sangat membantu. Sedikit...  2019-03-20 20:39:19
# 31  Over All sih bagus, Tetapi transaksiku kemarin...  2023-02-07 01:41:26
# 32  Zaman udh semakin maju,semua bisa di akses dr ...  2022-03-12 13:48:05
# 33  tolong di tingkatkan lagi aplikasinya, barusan...  2023-03-01 00:33:48
# 34  Terlalu sering nyuruh update.Padahal tidak ada...  2022-03-18 18:20:59
# 35  Aplikasinya memang sanggat membantu dalam peme...  2020-02-07 22:27:39
# 36  alangkah baiknya dijaka ditambah fitur (pilih ...  2019-06-09 09:19:27
# 37  Buat saya gada gangguan berarti dan aplikasi i...  2021-07-01 17:46:27
# 38  Semoga pemesanan tiket lokal bisa bayar via mi...  2020-01-19 22:34:20
# 39  Aplikasi yang keren dan selalu pake ini kalo m...  2019-08-12 23:31:10
# 40  Aplikasi ini sangatt baguss,cocok buat yg mage...  2021-10-26 22:21:28
# 41  Kebanyakan aturan setiap saat aturan berubah a...  2019-10-13 15:47:18
# 42  Saya sudah update tgl 21 September 2021, selam...  2021-10-04 06:28:52
# 43  Ketika beli tiket kereta api lokal bayarnya ha...  2019-09-18 11:59:05
# 44  Sangat memudahkan dalam memesan tiket kereta a...  2019-09-02 12:40:00
# 45  Saya ingin menyampaikan keluhan saya. Beberpaa...  2019-12-27 15:21:22
# 46  Tolong diperbaiki lagi soal boarding keberangk...  2021-02-28 16:40:22
# 47  Semakin ke sini semakin bagus,cm harap diperba...  2020-02-19 06:53:13
# 48  pesen tiket mudik via kai acces h-2 berhasil s...  2019-03-05 01:42:35
# 49  Pertama : Agar kiranya bisa edit nomor HP dan ...  2019-09-02 22:49:14
# 50  Kalau metode pembayaran untuk pembelian tiket ...  2021-09-24 19:58:08
# 51  tolong untuk pemesanan kereta lokal disediakan...  2019-03-10 20:53:52
# 52  Tolong dong. Tipe pembayaran tiket penataran/d...  2019-03-03 15:38:49
# 53  aplikasi nya bagus cukuo membantu tapi syangny...  2019-03-10 11:56:35
# 54  Tolong untuk server diperbaiki dong, sy udh be...  2019-10-07 17:31:13
# 55  Memudahkan penumpang pesan tiket, tapi sering ...  2019-08-25 20:59:52
# 56  Membuat pemesanan dan cetak tiket jadi lebih m...  2019-07-14 10:53:19
# 57  Untuk pt kai barusan saya update kok patah" sa...  2019-11-28 01:21:32
# 58  intinya, semua sudah berjalan baik. tinggal ti...  2019-09-03 22:46:07
# 59  Masukan untuk aplikasi KAI Access sebaiknya di...  2021-10-26 12:04:38
#
#    reviewer1 reviewer2 reviewer3  total_negative  total_positive     label
# 0   Positive  Positive  Negative               1               2  Positive
# 1   Positive  Positive  Negative               1               2  Positive
# 2   Positive  Positive  Negative               1               2  Positive
# 3   Positive  Positive  Negative               1               2  Positive
# 4   Positive  Positive  Negative               1               2  Positive
# 5   Positive  Positive  Negative               1               2  Positive
# 6   Positive  Positive  Negative               1               2  Positive
# 7   Positive  Positive  Negative               1               2  Positive
# 8   Positive  Positive  Negative               1               2  Positive
# 9   Positive  Positive  Negative               1               2  Positive
# 10  Positive  Positive  Negative               1               2  Positive
# 11  Positive  Negative  Positive               1               2  Positive
# 12  Positive  Positive  Negative               1               2  Positive
# 13  Positive  Negative  Positive               1               2  Positive
# 14  Positive  Positive  Negative               1               2  Positive
# 15  Positive  Positive  Negative               1               2  Positive
# 16  Positive  Negative  Positive               1               2  Positive
# 17  Positive  Positive  Negative               1               2  Positive
# 18  Positive  Positive  Negative               1               2  Positive
# 19  Positive  Positive  Negative               1               2  Positive
# 20  Positive  Positive  Negative               1               2  Positive
# 21  Positive  Positive  Negative               1               2  Positive
# 22  Positive  Positive  Negative               1               2  Positive
# 23  Positive  Positive  Negative               1               2  Positive
# 24  Positive  Positive  Negative               1               2  Positive
# 25  Positive  Positive  Negative               1               2  Positive
# 26  Positive  Negative  Positive               1               2  Positive
# 27  Positive  Positive  Negative               1               2  Positive
# 28  Positive  Positive  Negative               1               2  Positive
# 29  Positive  Negative  Positive               1               2  Positive
# 30  Positive  Positive  Negative               1               2  Positive
# 31  Positive  Positive  Negative               1               2  Positive
# 32  Positive  Negative  Positive               1               2  Positive
# 33  Positive  Positive  Negative               1               2  Positive
# 34  Positive  Negative  Positive               1               2  Positive
# 35  Positive  Positive  Negative               1               2  Positive
# 36  Positive  Negative  Positive               1               2  Positive
# 37  Positive  Positive  Negative               1               2  Positive
# 38  Positive  Positive  Negative               1               2  Positive
# 39  Positive  Positive  Negative               1               2  Positive
# 40  Positive  Positive  Negative               1               2  Positive
# 41  Positive  Positive  Negative               1               2  Positive
# 42  Positive  Negative  Positive               1               2  Positive
# 43  Positive  Positive  Negative               1               2  Positive
# 44  Positive  Negative  Positive               1               2  Positive
# 45  Positive  Positive  Negative               1               2  Positive
# 46  Positive  Negative  Positive               1               2  Positive
# 47  Positive  Positive  Negative               1               2  Positive
# 48  Positive  Positive  Negative               1               2  Positive
# 49  Positive  Positive  Negative               1               2  Positive
# 50  Positive  Positive  Negative               1               2  Positive
# 51  Positive  Positive  Negative               1               2  Positive
# 52  Positive  Positive  Negative               1               2  Positive
# 53  Positive  Positive  Negative               1               2  Positive
# 54  Positive  Positive  Negative               1               2  Positive
# 55  Positive  Positive  Negative               1               2  Positive
# 56  Positive  Positive  Negative               1               2  Positive
# 57  Positive  Positive  Negative               1               2  Positive
# 58  Positive  Positive  Negative               1               2  Positive
# 59  Positive  Positive  Negative               1               2  Positive

# %%
# menghapus kolom selain content, at, dan label
df.drop(df.columns[[2,3,4,5,6]], axis=1, inplace=True)
df
# Out:
#                                                 content                   at  \
# 0     Saya pertama kali coba aplikasi dan sangat kec...  2023-06-16 18:19:11
# 1     app in sering bikin jantung berdebar-debar gar...  2023-06-18 11:32:55
# 2     Bikin apk seperti niat tidak niat, saya udh da...  2023-06-10 14:20:19
# 3     Pembatalan tiket sangat Dipersulit, tidak Flek...  2023-06-20 13:05:54
# 4     KAI perusahaan besar dan bonafide, perombakan ...  2023-06-22 13:15:43
# ...                                                 ...                  ...
# 5995  Selalu setiap jam memasuki tiket go-show serve...  2022-10-19 06:15:55
# 5996  Mau ngebatalin tiket gabisa...disuruh perbaruh...  2020-05-02 04:29:55
# 5997  Makin ribet mana gak boleh pake screenshot tik...  2019-10-09 07:03:59
# 5998  Aplikasi tdk berguna, aplikasi sampah. Sering ...  2019-11-10 06:59:53
# 5999  Gimana sih ini aplikasi di perbarui malah pesa...  2019-11-25 18:27:49
#
#          label
# 0     Negative
# 1     Negative
# 2     Negative
# 3     Negative
# 4     Negative
# ...        ...
# 5995  Negative
# 5996  Negative
# 5997  Negative
# 5998  Negative
# 5999  Negative
#
# [6000 rows x 3 columns]

# %%
# cek fitur yang kosong
value_null = df['content'].isnull().sum()
# cek fitur yang memiliki kata 'tiket'
value_counts = df['content'].str.contains('tiket', case=False).sum()

print("Cek jumlah data (null) : ", value_null)
print("Cek jumlah kolom 'content' yang memiliki kata 'tiket' :", value_counts)

df.head()
# Out:
# Cek jumlah data (null) :  0
# Cek jumlah kolom 'content' yang memiliki kata 'tiket' : 6000
#                                              content                   at  \
# 0  Saya pertama kali coba aplikasi dan sangat kec...  2023-06-16 18:19:11
# 1  app in sering bikin jantung berdebar-debar gar...  2023-06-18 11:32:55
# 2  Bikin apk seperti niat tidak niat, saya udh da...  2023-06-10 14:20:19
# 3  Pembatalan tiket sangat Dipersulit, tidak Flek...  2023-06-20 13:05:54
# 4  KAI perusahaan besar dan bonafide, perombakan ...  2023-06-22 13:15:43
#
#       label
# 0  Negative
# 1  Negative
# 2  Negative
# 3  Negative
# 4  Negative

# %% [markdown]
# ### Analisis Keluhan Pengguna :

# %% [markdown]
# ##### _Dilakukan analisis keluhan pengguna terkait pemesanan, pembayaran, serta harga tiket._

# %% [markdown]
# 1. Pemesanan Tiket

# %%
# keyword yang dicari
keyword1 = 'pesan tiket'
keyword2 = 'pemesanan tiket'
keyword3 = 'order tiket'
keyword4 = 'book tiket'
keyword5 = 'booking tiket'

# data-data berdasarkan keyword
key1 = df['content'].str.contains(keyword1, case=False)
key2 = df['content'].str.contains(keyword2, case=False)
key3 = df['content'].str.contains(keyword3, case=False)
key4 = df['content'].str.contains(keyword4, case=False)
key5 = df['content'].str.contains(keyword5, case=False)    

# menggabungkan data-data
data_keluhan_pemesanan_tiket = key1 | key2 | key3 | key4 | key5

# membuat dataframe berisi keluhan pemesanan tiket
df_keluhan_pemesanan_tiket = df[data_keluhan_pemesanan_tiket]

# menghapus data yang duplicate
df_keluhan_pemesanan_tiket = df_keluhan_pemesanan_tiket.drop_duplicates()

# simpan keluhan
df_keluhan_pemesanan_tiket.to_excel("keluhan_pemesanan_tiket.xlsx", index=False)

print("\nTotal data keluhan pemesanan tiket :", len(df_keluhan_pemesanan_tiket))
df_keluhan_pemesanan_tiket.head().reset_index(drop=True)
# df_keluhan_pemesanan_tiket
# Out:
# Total data keluhan pemesanan tiket : 1482
#                                              content                   at  \
# 0  app in sering bikin jantung berdebar-debar gar...  2023-06-18 11:32:55
# 1  Bikin apk seperti niat tidak niat, saya udh da...  2023-06-10 14:20:19
# 2  Pembayaran QRIS masih bermasalah, saya barusan...  2023-04-17 08:22:32
# 3  Awal pake aplikasi ini sangat efisien dan baik...  2023-06-28 09:25:25
# 4  Mohon dicek apakah ada permasalahan pada aplik...  2023-06-21 11:53:00
#
#       label
# 0  Negative
# 1  Negative
# 2  Negative
# 3  Negative
# 4  Negative

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Keyword yang dicari
keywords = [keyword1, keyword2, keyword3, keyword4, keyword5]

# Mengonversi kolom 'at' menjadi tipe data datetime
df_keluhan_pemesanan_tiket['at'] = pd.to_datetime(df_keluhan_pemesanan_tiket['at'])

# Menghitung jumlah keluhan pemesanan tiket berdasarkan keyword untuk setiap tahun
df_keluhan_pemesanan_tiket['year'] = df_keluhan_pemesanan_tiket['at'].dt.year
keluhan_per_tahun = df_keluhan_pemesanan_tiket['content'].str.contains('|'.join(keywords), case=False).groupby(df_keluhan_pemesanan_tiket['year']).sum()

# Menggambar grafik histogram berdasarkan jumlah keluhan untuk setiap tahun
plt.figure(figsize=(10, 6))
bars = plt.bar(keluhan_per_tahun.index, keluhan_per_tahun.values, color='#58508d')
plt.xlabel('Tahun')
plt.ylabel('Jumlah Keluhan')
plt.title('Histogram: Keluhan Pemesanan Tiket')
plt.xticks(rotation=45, ha='right')

# Menambahkan label jumlahnya di setiap batang
for bar, count in zip(bars, keluhan_per_tahun.values):
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, height, count, ha='center', va='bottom', fontsize=10)

# legend
total_per_tahun = keluhan_per_tahun.sum()
plt.legend([f'{total_per_tahun} data (keluhan pemesanan tiket)'])

plt.tight_layout()
plt.show()

# %%
import re
import matplotlib.pyplot as plt

# df_keluhan_pemesanan_tiket['count_gagal'] = df_keluhan_pemesanan_tiket['content'].str.findall(r'\bgagal\b', flags=re.I).str.len()
df_keluhan_pemesanan_tiket['count_gagal'] = df_keluhan_pemesanan_tiket['content'].str.findall(r'gagal', flags=re.I).str.len()
df_keluhan_pemesanan_tiket['count_sulit'] = df_keluhan_pemesanan_tiket['content'].str.findall(r'sulit', flags=re.I).str.len()
df_keluhan_pemesanan_tiket['count_berhasil'] = df_keluhan_pemesanan_tiket['content'].str.findall(r'berhasil', flags=re.I).str.len()
df_keluhan_pemesanan_tiket['count_mudah'] = df_keluhan_pemesanan_tiket['content'].str.findall(r'mudah', flags=re.I).str.len()

total_gagal = df_keluhan_pemesanan_tiket['count_gagal'].sum()
total_sulit = df_keluhan_pemesanan_tiket['count_sulit'].sum()
total_berhasil = df_keluhan_pemesanan_tiket['count_berhasil'].sum()
total_mudah = df_keluhan_pemesanan_tiket['count_mudah'].sum()
total_data = total_gagal + total_berhasil + total_sulit + total_mudah

# Warna untuk setiap bar (misalnya: merah untuk 'gagal' dan biru untuk 'berhasil')
colors = ['#9086b9', '#c9c0e7','#aca2d0','#746aa3']

# Menampilkan histogram
plt.figure(figsize=(8, 6))

# Plot bar
bars = plt.bar(['Gagal', 'Sulit', 'Berhasil', 'Mudah'], [total_gagal, total_sulit, total_berhasil , total_mudah], color=colors)

# Menambahkan jumlah di atas setiap batang
for bar in bars:
    height = bar.get_height()
    plt.annotate('{}'.format(height),
                 xy=(bar.get_x() + bar.get_width() / 2, height),
                 xytext=(0, 3),  # 3 points vertical offset
                 textcoords="offset points",
                 ha='center', va='bottom', fontsize=10)

plt.xlabel('Kategori')
plt.ylabel('Jumlah')
plt.title('Kategori Umum dalam Keluhan Pemesanan Tiket', size=10)

# Membuat legend untuk menghitung total data
plt.legend([f'Total: {total_data} '])

plt.show()

# %% [markdown]
# 2. Pembayaran Tiket

# %%
# keyword yang dicari
keyword1 = 'pembayaran tiket'
keyword2 = 'bayar tiket'
keyword3 = 'payment tiket'

# data-data berdasarkan keyword
key1 = df['content'].str.contains(keyword1, case=False)
key2 = df['content'].str.contains(keyword2, case=False)
key3 = df['content'].str.contains(keyword3, case=False)

# menggabungkan data-data
data_keluhan_pembayaran_tiket = key1 | key2 | key3

# membuat dataframe berisi keluhan pemesanan tiket
df_keluhan_pembayaran_tiket = df[data_keluhan_pembayaran_tiket]

# menghapus data yang duplicate
df_keluhan_pembayaran_tiket = df_keluhan_pembayaran_tiket.drop_duplicates()

# simpan keluhan
df_keluhan_pembayaran_tiket.to_excel("keluhan_pembayaran_tiket.xlsx", index=False)

print("\nTotal data keluhan pemesanan tiket :", len(df_keluhan_pembayaran_tiket))
df_keluhan_pembayaran_tiket.head().reset_index(drop=True)
# df_keluhan_pemesanan_tiket
# Out:
# Total data keluhan pemesanan tiket : 175
#                                              content                   at  \
# 0  kenapa pembayaran qris tidak bisa membayar tik...  2023-06-20 10:08:05
# 1  Aplikasinya sangat tidak competible. Saya mela...  2023-04-22 11:07:25
# 2  Pelayanan aplikasi masih tidak jelas, saya top...  2023-05-31 21:30:01
# 3  katanya pake KAI untuk mempermudah. tapi setia...  2023-05-19 20:43:46
# 4  Jelek sekali pelayanan aplikasi ini. Biasanya ...  2023-04-17 00:07:31
#
#       label
# 0  Negative
# 1  Negative
# 2  Negative
# 3  Negative
# 4  Negative

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Keyword yang dicari
keywords = [keyword1, keyword2, keyword3]

df_keluhan_pembayaran_tiket['at'] = pd.to_datetime(df_keluhan_pembayaran_tiket['at'])
# Menghitung jumlah keluhan pemesanan tiket berdasarkan keyword untuk setiap tahun
df_keluhan_pembayaran_tiket['year'] = df_keluhan_pembayaran_tiket['at'].dt.year
keluhan_per_tahun = df_keluhan_pembayaran_tiket['content'].str.contains('|'.join(keywords), case=False).groupby(df_keluhan_pembayaran_tiket['year']).sum()

# Menggambar grafik histogram berdasarkan jumlah keluhan untuk setiap tahun
plt.figure(figsize=(10, 6))
bars = plt.bar(keluhan_per_tahun.index, keluhan_per_tahun.values, color='#ff6361')
plt.xlabel('Tahun')
plt.ylabel('Jumlah Keluhan')
plt.title('Histogram: Keluhan Pembayaran Tiket')
plt.xticks(rotation=45, ha='right')

# Menambahkan label jumlahnya di setiap batang
for bar, count in zip(bars, keluhan_per_tahun.values):
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, height, count, ha='center', va='bottom', fontsize=10)

# legend
total_per_tahun = keluhan_per_tahun.sum()
plt.legend([f'{total_per_tahun} data (keluhan pembayaran tiket)'])

plt.tight_layout()
plt.show()

# %%
import re
import matplotlib.pyplot as plt

df_keluhan_pembayaran_tiket['count_gagal'] = df_keluhan_pembayaran_tiket['content'].str.findall(r'gagal', flags=re.I).str.len()
df_keluhan_pembayaran_tiket['count_berhasil'] = df_keluhan_pembayaran_tiket['content'].str.findall(r'berhasil', flags=re.I).str.len()
df_keluhan_pembayaran_tiket['count_sulit'] = df_keluhan_pembayaran_tiket['content'].str.findall(r'sulit', flags=re.I).str.len()
df_keluhan_pembayaran_tiket['count_mudah'] = df_keluhan_pembayaran_tiket['content'].str.findall(r'mudah', flags=re.I).str.len()
df_keluhan_pembayaran_tiket['count_linkaja'] = df_keluhan_pembayaran_tiket['content'].str.findall(r'linkaja', flags=re.I).str.len()
df_keluhan_pembayaran_tiket['count_qris'] = df_keluhan_pembayaran_tiket['content'].str.findall(r'qris', flags=re.I).str.len()

total_gagal = df_keluhan_pembayaran_tiket['count_gagal'].sum()
total_berhasil = df_keluhan_pembayaran_tiket['count_berhasil'].sum()
total_sulit = df_keluhan_pembayaran_tiket['count_sulit'].sum()
total_mudah = df_keluhan_pembayaran_tiket['count_mudah'].sum()
total_linkaja = df_keluhan_pembayaran_tiket['count_linkaja'].sum()
total_qris = df_keluhan_pembayaran_tiket['count_qris'].sum()
total_data = total_gagal + total_berhasil + total_sulit + total_mudah + total_metode + total_linkaja + total_qris

colors = ['#ff7d76', '#ffaba2','#ffd6d1','#ff6361', 
          #'#ffc1b9'#,
          '#ff6361','#ff948c']

# Menampilkan histogram
plt.figure(figsize=(8, 6))

# Plot bar
bars = plt.bar(['Gagal','Berhasil','Sulit', 'Mudah', 'LinkAja', 'QRIS'], [total_gagal, total_berhasil, total_sulit, total_mudah, total_linkaja, total_qris], color=colors)

# Menambahkan jumlah di atas setiap batang
for bar in bars:
    height = bar.get_height()
    plt.annotate('{}'.format(height),
                 xy=(bar.get_x() + bar.get_width() / 2, height),
                 xytext=(0, 3),  # 3 points vertical offset
                 textcoords="offset points",
                 ha='center', va='bottom', fontsize=10)

plt.xlabel('Kategori')
plt.ylabel('Jumlah')
plt.title('Kategori Umum dalam Keluhan Pembayaran Tiket', size=10)

# Membuat legend untuk menghitung total data
plt.legend([f'Total: {total_data} '])

plt.show()

# %% [markdown]
# 3. Harga Tiket

# %%
# keyword yang dicari
keyword1 = 'harga tiket'
keyword2 = 'promo tiket'

# data-data berdasarkan keyword
key1 = df['content'].str.contains(keyword1, case=False)
key2 = df['content'].str.contains(keyword2, case=False)

# menggabungkan data-data
data_keluhan_harga_tiket = key1 | key2

# membuat dataframe berisi keluhan pemesanan tiket
df_keluhan_harga_tiket = df[data_keluhan_harga_tiket]

# menghapus data yang duplicate
df_keluhan_harga_tiket = df_keluhan_harga_tiket.drop_duplicates()

# simpan keluhan
df_keluhan_harga_tiket.to_excel("keluhan_harga_tiket.xlsx", index=False)

print("\nTotal data keluhan pemesanan tiket :", len(df_keluhan_harga_tiket))
df_keluhan_harga_tiket.head().reset_index(drop=True)
# Out:
# Total data keluhan pemesanan tiket : 74
#                                              content                   at  \
# 0  kenapa pembayaran qris tidak bisa membayar tik...  2023-06-20 10:08:05
# 1  Dari kemarin mau booking tiket malah gagal, mu...  2023-06-01 05:44:13
# 2  Buruk banget aplikasinya suka lemot !!padahal ...  2023-04-25 15:49:39
# 3  Bila di pesan sulit , hanya munculnya harga ya...  2023-04-20 16:15:24
# 4  Sudah beli in tiket buat keluarga tapi tidak d...  2023-02-06 13:21:50
#
#       label
# 0  Negative
# 1  Negative
# 2  Negative
# 3  Negative
# 4  Negative

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Keyword yang dicari
keywords = [keyword1, keyword2]

df_keluhan_harga_tiket['at'] = pd.to_datetime(df_keluhan_harga_tiket['at'])
# Menghitung jumlah keluhan pemesanan tiket berdasarkan keyword untuk setiap tahun
df_keluhan_harga_tiket['year'] = df_keluhan_harga_tiket['at'].dt.year
keluhan_per_tahun = df_keluhan_harga_tiket['content'].str.contains('|'.join(keywords), case=False).groupby(df_keluhan_harga_tiket['year']).sum()

# Menggambar grafik histogram berdasarkan jumlah keluhan untuk setiap tahun
plt.figure(figsize=(10, 6))
bars = plt.bar(keluhan_per_tahun.index, keluhan_per_tahun.values, color='#439981')
plt.xlabel('Tahun')
plt.ylabel('Jumlah Keluhan')
plt.title('Histogram: Keluhan Harga Tiket')
plt.xticks(rotation=45, ha='right')

# Menambahkan label jumlahnya di setiap batang
for bar, count in zip(bars, keluhan_per_tahun.values):
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, height, count, ha='center', va='bottom', fontsize=10)

# legend
total_per_tahun = keluhan_per_tahun.sum()
plt.legend([f'{total_per_tahun} data (keluhan harga tiket)'])

plt.tight_layout()
plt.show()

# %%
import re
import matplotlib.pyplot as plt

df_keluhan_harga_tiket['count_mahal'] = df_keluhan_harga_tiket['content'].str.findall(r'mahal', flags=re.I).str.len()
df_keluhan_harga_tiket['count_murah'] = df_keluhan_harga_tiket['content'].str.findall(r'murah', flags=re.I).str.len()
df_keluhan_harga_tiket['count_promo'] = df_keluhan_harga_tiket['content'].str.findall(r'promo', flags=re.I).str.len()

total_mahal = df_keluhan_harga_tiket['count_mahal'].sum()
total_murah = df_keluhan_harga_tiket['count_murah'].sum()
total_promo = df_keluhan_harga_tiket['count_promo'].sum()
total_data = total_mahal + total_murah + total_promo

colors = ['#439981', '#5ca992','#74baa4']

# Menampilkan histogram
plt.figure(figsize=(8, 6))

# Plot bar
bars = plt.bar(['Mahal','Murah','Promo'], [total_mahal, total_murah, total_promo], color=colors)

# Menambahkan jumlah di atas setiap batang
for bar in bars:
    height = bar.get_height()
    plt.annotate('{}'.format(height),
                 xy=(bar.get_x() + bar.get_width() / 2, height),
                 xytext=(0, 3),  # 3 points vertical offset
                 textcoords="offset points",
                 ha='center', va='bottom', fontsize=10)

plt.xlabel('Kategori')
plt.ylabel('Jumlah')
plt.title('Kategori Umum dalam Keluhan Harga Tiket', size=10)

# Membuat legend untuk menghitung total data
plt.legend([f'Total: {total_data} '])

plt.show()

# %% [markdown]
# ## 2. Data Cleaning :

# %% [markdown]
# ### 2.1 Casefolding

# %% [markdown]
# <i>Proses melakukan konversi teks. Mengubah huruf besar menjadi huruf kecil, dan mengubah huruf aksen ke bentuk tanpa aksen yang setara (mis: huruf é menjadi e, huruf E menjadi e).

# %%
from unidecode import unidecode

def casefolding(text):
    text = text.lower()
    text = unidecode(text)
    
    return text

df['cleaning'] = df['content'].apply(casefolding)

# %%
df[['cleaning']].head()
# Out:
#                                             cleaning
# 0  saya pertama kali coba aplikasi dan sangat kec...
# 1  app in sering bikin jantung berdebar-debar gar...
# 2  bikin apk seperti niat tidak niat, saya udh da...
# 3  pembatalan tiket sangat dipersulit, tidak flek...
# 4  kai perusahaan besar dan bonafide, perombakan ...

# %% [markdown]
# ### 2.2 Cleansing

# %% [markdown]
# <i>Proses membersihkan atau membuang noise (angka, tanda baca, emoji, multi spasi, dan baris enter)

# %%
import re

def cleansing(text):
    
    # menghapus karakter yang bukan huruf, angka, atau spasi
    text = re.sub(r'[^\w\s]', ' ', text)
    # menghapus angka menjadi satu spasi
    text = re.sub(r'\d+', '', text)
    # menghapus multi-spasi menjadi satu spasi
    text = re.sub(r'\s+', ' ', text).strip()
    
    return text

df['cleaning'] = df['cleaning'].apply(cleansing)

# %%
df[['cleaning']].head()
# Out:
#                                             cleaning
# 0  saya pertama kali coba aplikasi dan sangat kec...
# 1  app in sering bikin jantung berdebar debar gar...
# 2  bikin apk seperti niat tidak niat saya udh daf...
# 3  pembatalan tiket sangat dipersulit tidak fleks...
# 4  kai perusahaan besar dan bonafide perombakan b...

# %%
# hasil cleaning
df.head(5)
# Out:
#                                              content                   at  \
# 0  Saya pertama kali coba aplikasi dan sangat kec...  2023-06-16 18:19:11
# 1  app in sering bikin jantung berdebar-debar gar...  2023-06-18 11:32:55
# 2  Bikin apk seperti niat tidak niat, saya udh da...  2023-06-10 14:20:19
# 3  Pembatalan tiket sangat Dipersulit, tidak Flek...  2023-06-20 13:05:54
# 4  KAI perusahaan besar dan bonafide, perombakan ...  2023-06-22 13:15:43
#
#       label                                           cleaning
# 0  Negative  saya pertama kali coba aplikasi dan sangat kec...
# 1  Negative  app in sering bikin jantung berdebar debar gar...
# 2  Negative  bikin apk seperti niat tidak niat saya udh daf...
# 3  Negative  pembatalan tiket sangat dipersulit tidak fleks...
# 4  Negative  kai perusahaan besar dan bonafide perombakan b...

# %% [markdown]
# ## 3. Data Normalize :

# %% [markdown]
# ### 3.1 Stemming

# %% [markdown]
# <i>Proses menemukan kata dasar dengan menghilangkan semua imbuhan yang menyatu pada kata. Misalnya kata "diperbaiki" akan diubah menjadi "baik".

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

factory = StemmerFactory()
stemmer = factory.create_stemmer()
    
def stemming(text):
    
    stemmed_text = stemmer.stem(text)
    return stemmed_text

df['normalize'] = df['cleaning'].apply(stemming)

# %%
df[['normalize']].head()
# Out:
#                                            normalize
# 0  saya pertama kali coba aplikasi dan sangat kec...
# 1  app in sering bikin jantung debar debar gara t...
# 2  bikin apk seperti niat tidak niat saya udh daf...
# 3  batal tiket sangat sulit tidak fleksibel harus...
# 4  kai usaha besar dan bonafide ombak besar laku ...

# %% [markdown]
# ### 3.2 Slang Word Normalization

# %% [markdown]
# <i>Proses mengubah kata non-baku (slang) menjadi kata baku.

# %%
kbba_dictionary = pd.read_csv(
    'https://raw.githubusercontent.com/insomniagung/kamus_kbba/main/kbba.txt', 
    delimiter='\t', names=['slang', 'formal'], header=None, encoding='utf-8')

slang_dict = dict(zip(kbba_dictionary['slang'], kbba_dictionary['formal']))
kbba_dictionary.iloc[0:5]
# Out:
#     slang     formal
# 0     7an     tujuan
# 1       @         di
# 2  ababil  abg labil
# 3    abis      habis
# 4     acc     terima

# %%
def convert_slangword(text):
    words = text.split()
    
    normalized_words = [slang_dict[word] if word in slang_dict else word for word in words]
    normalized_text = ' '.join(normalized_words)
    return normalized_text

df['normalize'] = df['normalize'].apply(convert_slangword)

# %%
df[['normalize']].head()
# Out:
#                                            normalize
# 0  saya pertama kali coba aplikasi dan sangat kec...
# 1  aplikasi in sering bikin jantung debar debar g...
# 2  bikin aplikasi seperti niat tidak niat saya su...
# 3  batal tiket sangat sulit tidak fleksibel harus...
# 4  kai usaha besar dan bonafide ombak besar laku ...

# %%
# hasil normalize
df.head(11)
# Out:
#                                               content                   at  \
# 0   Saya pertama kali coba aplikasi dan sangat kec...  2023-06-16 18:19:11
# 1   app in sering bikin jantung berdebar-debar gar...  2023-06-18 11:32:55
# 2   Bikin apk seperti niat tidak niat, saya udh da...  2023-06-10 14:20:19
# 3   Pembatalan tiket sangat Dipersulit, tidak Flek...  2023-06-20 13:05:54
# 4   KAI perusahaan besar dan bonafide, perombakan ...  2023-06-22 13:15:43
# 5   Setelah di-update banyak sekali masalah dan bu...  2023-06-05 23:30:49
# 6   Seringkali aplikasi tidak berjalan lancar teru...  2023-05-10 10:38:45
# 7   Pembayaran QRIS masih bermasalah, saya barusan...  2023-04-17 08:22:32
# 8   Aplikasi terlalu lemot. Mohon untuk di perbaik...  2023-07-05 14:36:15
# 9   App ini cuma lancar untuk pembelian tiket KA b...  2023-07-02 10:37:44
# 10  Awal pake aplikasi ini sangat efisien dan baik...  2023-06-28 09:25:25
#
#        label                                           cleaning  \
# 0   Negative  saya pertama kali coba aplikasi dan sangat kec...
# 1   Negative  app in sering bikin jantung berdebar debar gar...
# 2   Negative  bikin apk seperti niat tidak niat saya udh daf...
# 3   Negative  pembatalan tiket sangat dipersulit tidak fleks...
# 4   Negative  kai perusahaan besar dan bonafide perombakan b...
# 5   Negative  setelah di update banyak sekali masalah dan bu...
# 6   Negative  seringkali aplikasi tidak berjalan lancar teru...
# 7   Negative  pembayaran qris masih bermasalah saya barusan ...
# 8   Negative  aplikasi terlalu lemot mohon untuk di perbaiki...
# 9   Negative  app ini cuma lancar untuk pembelian tiket ka b...
# 10  Negative  awal pake aplikasi ini sangat efisien dan baik...
#
#                                             normalize
# 0   saya pertama kali coba aplikasi dan sangat kec...
# 1   aplikasi in sering bikin jantung debar debar g...
# 2   bikin aplikasi seperti niat tidak niat saya su...
# 3   batal tiket sangat sulit tidak fleksibel harus...
# 4   kai usaha besar dan bonafide ombak besar laku ...
# 5   telah di perbarui banyak sekali masalah dan bu...
# 6   seringkali aplikasi tidak jalan lancar utama s...
# 7   bayar qris masih masalah saya barusan pesan ti...
# 8   aplikasi terlalu lambat mohon untuk di baik da...
# 9   aplikasi ini cuma lancar untuk beli tiket kaka...
# 10  awal pakai aplikasi ini sangat efisien dan bai...

# %% [markdown]
# ## 4. Words Removal :

# %% [markdown]
# ### 4.1 Stopword Removal

# %% [markdown]
# <i>Proses menghapus seluruh kata yang dianggap tidak memiliki makna. Seperti kata hubung "yang", "di", "dan", "dari".

# %%
from nlp_id.stopword import StopWord

def remove_stopword(text):
    stopword = StopWord()
    text = stopword.remove_stopword(text)
    return text

df['removal'] = df['normalize'].apply(remove_stopword)

# %%
df[['removal']].head(5)
# Out:
#                                              removal
# 0  coba aplikasi kecewa pesan bd bks transfer tik...
# 1  aplikasi in bikin jantung debar debar gara pro...
# 2  bikin aplikasi niat niat daftar pesan tiket su...
# 3  batal tiket sulit fleksibel akun kai acces mud...
# 4  kai usaha besar bonafide ombak besar laku tata...

# %% [markdown]
# ### 4.2 Unwanted Word Removal

# %% [markdown]
# <i>Proses membuat dictionary kata-kata yang kurang dianggap bermakna secara manual, lalu menghapus kata yang sama dari ulasan. Kata yang dianggap tidak bermakna yaitu seperti nama bulan dalam kalender.

# %%
from nltk.tokenize import word_tokenize

def remove_unwanted_words(text):
    unwanted_words = {'jan', 'feb', 'mar', 'apr', 'may', 'jun', 'jul', 'aug', 
                      'sep', 'oct', 'nov', 'dec', 'januari', 'februari', 'maret', 
                      'april', 'mei', 'juni', 'juli', 'agustus', 'september', 
                      'oktober', 'november', 'desember', 'gin'}
    
    word_tokens = word_tokenize(text)
    filtered_words = [word for word in word_tokens if word not in unwanted_words]
    filtered_text = ' '.join(filtered_words)
    
    return filtered_text

df['removal'] = df['removal'].apply(remove_unwanted_words)

# %%
df[['removal']].head(5)
# Out:
#                                              removal
# 0  coba aplikasi kecewa pesan bd bks transfer tik...
# 1  aplikasi in bikin jantung debar debar gara pro...
# 2  bikin aplikasi niat niat daftar pesan tiket su...
# 3  batal tiket sulit fleksibel akun kai acces mud...
# 4  kai usaha besar bonafide ombak besar laku tata...

# %% [markdown]
# ### 4.3 Short Word Removal

# %% [markdown]
# <i>Proses menghapus kata apapun yang kurang dari 3 karakter. Seperti kata 'di'.

# %%
def remove_short_words(text):
    return ' '.join([word for word in text.split() if len(word) >= 3])

df['removal'] = df['removal'].apply(remove_short_words)

# %%
df[['removal']].head(5)
# Out:
#                                              removal
# 0  coba aplikasi kecewa pesan bks transfer tiket ...
# 1  aplikasi bikin jantung debar debar gara proses...
# 2  bikin aplikasi niat niat daftar pesan tiket su...
# 3  batal tiket sulit fleksibel akun kai acces mud...
# 4  kai usaha besar bonafide ombak besar laku tata...

# %%
# hasil words removal
df.head(5)
# Out:
#                                              content                   at  \
# 0  Saya pertama kali coba aplikasi dan sangat kec...  2023-06-16 18:19:11
# 1  app in sering bikin jantung berdebar-debar gar...  2023-06-18 11:32:55
# 2  Bikin apk seperti niat tidak niat, saya udh da...  2023-06-10 14:20:19
# 3  Pembatalan tiket sangat Dipersulit, tidak Flek...  2023-06-20 13:05:54
# 4  KAI perusahaan besar dan bonafide, perombakan ...  2023-06-22 13:15:43
#
#       label                                           cleaning  \
# 0  Negative  saya pertama kali coba aplikasi dan sangat kec...
# 1  Negative  app in sering bikin jantung berdebar debar gar...
# 2  Negative  bikin apk seperti niat tidak niat saya udh daf...
# 3  Negative  pembatalan tiket sangat dipersulit tidak fleks...
# 4  Negative  kai perusahaan besar dan bonafide perombakan b...
#
#                                            normalize  \
# 0  saya pertama kali coba aplikasi dan sangat kec...
# 1  aplikasi in sering bikin jantung debar debar g...
# 2  bikin aplikasi seperti niat tidak niat saya su...
# 3  batal tiket sangat sulit tidak fleksibel harus...
# 4  kai usaha besar dan bonafide ombak besar laku ...
#
#                                              removal
# 0  coba aplikasi kecewa pesan bks transfer tiket ...
# 1  aplikasi bikin jantung debar debar gara proses...
# 2  bikin aplikasi niat niat daftar pesan tiket su...
# 3  batal tiket sulit fleksibel akun kai acces mud...
# 4  kai usaha besar bonafide ombak besar laku tata...

# %% [markdown]
# ## 5. Tokenizing  :

# %% [markdown]
# ### 5.1 Split Words

# %% [markdown]
# <i>Proses pemisahan kata pada tiap ulasan.

# %%
from nlp_id.tokenizer import Tokenizer
tokenizer = Tokenizer()

def tokenizing(text):
    return tokenizer.tokenize(text)

df['tokenizing'] = df['removal'].apply(tokenizing)

# %%
df[['tokenizing']].head()
# Out:
#                                           tokenizing
# 0  [coba, aplikasi, kecewa, pesan, bks, transfer,...
# 1  [aplikasi, bikin, jantung, debar, debar, gara,...
# 2  [bikin, aplikasi, niat, niat, daftar, pesan, t...
# 3  [batal, tiket, sulit, fleksibel, akun, kai, ac...
# 4  [kai, usaha, besar, bonafide, ombak, besar, la...

# %% [markdown]
# ### 5.2 Pie Chart

# %% [markdown]
# Proses melakukan visualisasi jumlah sentimen positive & negative menggunakan Pie Chart.

# %%
import matplotlib.pyplot as plt

# df_sub = df.loc[df.polarity.isin(['positive', 'negative'])]
df_sub = df.loc[df['label'].isin(['Positive', 'Negative'])]

sizes = [count for count in df_sub['label'].value_counts()]
explode = (0.1, 0)
total_sizes = sum(sizes)
fig, ax = plt.subplots(figsize=(6, 6), facecolor='none')
labels = ['Negative', 'Positive']
colors = ['#ff9999', '#66b3ff']
wedgeprops = {'width': 0.7, 'edgecolor': 'white', 'linewidth': 2}
pie = ax.pie(x=sizes, labels=['', ''], colors=colors, explode=explode,
    autopct=lambda pct: "{:.1f}%\n({:d})".format(pct, int(pct / 100 * total_sizes)),
    textprops={'fontsize': 9, 'color': 'black'}, shadow=True,
    wedgeprops=wedgeprops)
ax.legend(pie[0], labels, loc='center left', fontsize=10)
ax.set_title(f"Sentiment Analysis on KAI Access Reviews \n(Total: {total_sizes} reviews)", 
             fontsize=10, color='black', pad=4)
plt.show(fig)

# %% [markdown]
# ### 5.3 Wordcloud

# %% [markdown]
# <i>Proses menampilkan seluruh kata dalam sentimen pada Wordcloud. Jika kata semakin sering muncul, maka ditampilkan dengan ukuran yang lebih besar.

# %%
from collections import Counter
from wordcloud import WordCloud, ImageColorGenerator
from PIL import Image
import numpy as np

# positive_words = df[df.polarity == 'positive']['tokenizing'].apply(pd.Series).stack().tolist()
positive_words = df[df['label'] == 'Positive']['tokenizing'].apply(pd.Series).stack().tolist()
positive_word_counts = Counter(positive_words)

# negative_words = df[df.polarity == 'negative']['tokenizing'].apply(pd.Series).stack().tolist()
negative_words = df[df['label'] == 'Negative']['tokenizing'].apply(pd.Series).stack().tolist()
negative_word_counts = Counter(negative_words)

mask_pos = np.array(Image.open("img/train_pos.jpg"))
mask_neg = np.array(Image.open("img/train_neg.jpg"))

positive_wordcloud = WordCloud(width=1000, height=800, mask=mask_pos, max_words=2000,
                               background_color='black').generate_from_frequencies(positive_word_counts)

negative_wordcloud = WordCloud(width=1000, height=800, mask=mask_neg, max_words=2000,
                               background_color='black').generate_from_frequencies(negative_word_counts)

figPos, axPos = plt.subplots(figsize=(9, 4))
axPos.imshow(positive_wordcloud.recolor(color_func=ImageColorGenerator(mask_pos)), interpolation='bilinear')
axPos.axis('off')
plt.show(figPos)

figNeg, axNeg = plt.subplots(figsize=(9, 4))
axNeg.imshow(negative_wordcloud.recolor(color_func=ImageColorGenerator(mask_neg)), interpolation='bilinear')
axNeg.axis('off')
plt.show(figNeg)

# %% [markdown]
# ## 6. Filter Data Uji dan TF-IDF

# %% [markdown]
# ### 6.1 Filter Data : 1200 Positive dan 1200 Negative

# %%
# memfilter label menjadi 1200 positive dan 1200 negative
df[['content','label','tokenizing']][df['label'] == 'Positive'].head(1200).to_excel("1200_positive.xlsx", index=False)
df[['content','label','tokenizing']][df['label'] == 'Negative'].head(1200).to_excel("1200_negative.xlsx", index=False)

# menggabungkan label
df_1200_pos = pd.read_excel('1200_positive.xlsx')
df_1200_neg = pd.read_excel('1200_negative.xlsx')
df_2400_neg_pos = pd.concat([df_1200_pos, df_1200_neg], ignore_index=True, sort=False)
print(len(df_2400_neg_pos))
df_2400_neg_pos
# Out:
# 2400
#                                                 content     label  \
# 0     Mohon tingkatkan kembali kualitasnya baik perf...  Positive
# 1     Saya ada sedikit masalah setelah meng-update a...  Positive
# 2     Kemarin sempat kasih ⭐️1 alhamdulillah sekaran...  Positive
# 3     Aplikasinya udah bagus. Saya suka fitur untuk ...  Positive
# 4     Menurutku app ini sangat berguna saat kita mau...  Positive
# ...                                                 ...       ...
# 2395  Aplikasi ampas mempersulit penumpang memesan t...  Negative
# 2396  Ribeeet banget.. Sistemnya harus autodebit dar...  Negative
# 2397   Aplikasi belum sempurna jadi ribet beli tiketnya  Negative
# 2398  Tolong dikasi konfirmasi 2x pasword kek atau a...  Negative
# 2399  Kai makin lemot susah untuk pesan tiketnya har...  Negative
#
#                                              tokenizing
# 0     ['mohon', 'tingkat', 'kualitas', 'performa', '...
# 1     ['meng', 'perbarui', 'aplikasi', 'versi', 'nom...
# 2     ['kemarin', 'kasih', 'aplikasi', 'lancar', 'mu...
# 3     ['aplikasi', 'bagus', 'suka', 'fitur', 'simpan...
# 4     ['aplikasi', 'pesan', 'tiket', 'jadwal', 'kere...
# ...                                                 ...
# 2395  ['aplikasi', 'ampas', 'sulit', 'tumpang', 'mes...
# 2396  ['ribeeet', 'sistem', 'autodebit', 'saldo', 'l...
# 2397  ['aplikasi', 'sempurna', 'ribet', 'beli', 'tik...
# 2398  ['tolong', 'kasi', 'konfirmasi', 'pasword', 'm...
# 2399  ['kai', 'lambat', 'susah', 'pesan', 'tiket', '...
#
# [2400 rows x 3 columns]

# %%
# menyimpan 2400 data pos dan neg
df_2400_neg_pos.to_excel("2400_pos_neg.xlsx", index=False)
df = df_2400_neg_pos

cek_jumlah_positive = len(df[['content','label','tokenizing']][df['label'] == 'Positive'])
cek_jumlah_negative = len(df[['content','label','tokenizing']][df['label'] == 'Negative'])

print("Total Data Pengujian: ", len(df))
print("Jumlah Positive: ", cek_jumlah_positive)
print("Jumlah Negative: ", cek_jumlah_negative)

df
# Out:
# Total Data Pengujian:  2400
# Jumlah Positive:  1200
# Jumlah Negative:  1200
#                                                 content     label  \
# 0     Mohon tingkatkan kembali kualitasnya baik perf...  Positive
# 1     Saya ada sedikit masalah setelah meng-update a...  Positive
# 2     Kemarin sempat kasih ⭐️1 alhamdulillah sekaran...  Positive
# 3     Aplikasinya udah bagus. Saya suka fitur untuk ...  Positive
# 4     Menurutku app ini sangat berguna saat kita mau...  Positive
# ...                                                 ...       ...
# 2395  Aplikasi ampas mempersulit penumpang memesan t...  Negative
# 2396  Ribeeet banget.. Sistemnya harus autodebit dar...  Negative
# 2397   Aplikasi belum sempurna jadi ribet beli tiketnya  Negative
# 2398  Tolong dikasi konfirmasi 2x pasword kek atau a...  Negative
# 2399  Kai makin lemot susah untuk pesan tiketnya har...  Negative
#
#                                              tokenizing
# 0     ['mohon', 'tingkat', 'kualitas', 'performa', '...
# 1     ['meng', 'perbarui', 'aplikasi', 'versi', 'nom...
# 2     ['kemarin', 'kasih', 'aplikasi', 'lancar', 'mu...
# 3     ['aplikasi', 'bagus', 'suka', 'fitur', 'simpan...
# 4     ['aplikasi', 'pesan', 'tiket', 'jadwal', 'kere...
# ...                                                 ...
# 2395  ['aplikasi', 'ampas', 'sulit', 'tumpang', 'mes...
# 2396  ['ribeeet', 'sistem', 'autodebit', 'saldo', 'l...
# 2397  ['aplikasi', 'sempurna', 'ribet', 'beli', 'tik...
# 2398  ['tolong', 'kasi', 'konfirmasi', 'pasword', 'm...
# 2399  ['kai', 'lambat', 'susah', 'pesan', 'tiket', '...
#
# [2400 rows x 3 columns]

# %% [markdown]
# ### 6.2 Pembobotan TF-IDF

# %% [markdown]
# <i>Proses memberikan nilai bobot pada dokumen. Proses TF-IDF (Term Frequency-Inverse Document Frequency) tujuannya untuk mengetahui seberapa penting suatu kata dalam dokumen tersebut.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

df = df.copy()
df['tokenizing'] = df['tokenizing'].astype(str)
review = df['tokenizing'].values.tolist()

tf_idf = TfidfVectorizer()
tf_idf_vector = tf_idf.fit(review)
X = tf_idf_vector.transform(review)
y = df['label']

print(X[0:2])
# Out:
#   (0, 3189)	0.3153017441033409
#   (0, 3164)	0.06779674269606953
#   (0, 2816)	0.42650040800690586
#   (0, 2387)	0.4323921297565337
#   (0, 2015)	0.3176900632169866
#   (0, 1994)	0.2307873100227608
#   (0, 1622)	0.4070208550808078
#   (0, 1488)	0.17065086296873705
#   (0, 547)	0.2829329433446506
#   (0, 304)	0.17077996135854295
#   (0, 168)	0.1143370163672293
#   (0, 160)	0.23633791223511266
#   (1, 3379)	0.36564213910904225
#   (1, 3313)	0.318554769777252
#   (1, 3296)	0.14051279817329376
#   (1, 3212)	0.10607225575460022
#   (1, 3164)	0.037419535548252385
#   (1, 2941)	0.19331918097762857
#   (1, 2710)	0.17226074786354031
#   (1, 2381)	0.1296998928551886
#   (1, 2156)	0.33283531182514425
#   (1, 1944)	0.11154094255264921
#   (1, 1908)	0.2764596138350946
#   (1, 1617)	0.20650510710315267
#   (1, 1373)	0.08743403756045205
#   (1, 867)	0.22964034169480785
#   (1, 741)	0.5744222024207578
#   (1, 168)	0.12621367571049077

# %% [markdown]
# ## 7. Modeling :

# %% [markdown]
# ### 7.1 Split Data (Train & Test)

# %% [markdown]
# <i>Proses pemisahan data latih (train) & data uji (test).

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.9, random_state=0)
all_data = len(y)
data_train = len(y_train)
data_test = len(y_test)
vector = X_train.shape, X_test.shape

print("Total Data : ", all_data)
print("Data Latih : ", data_train)
print("Data Uji : ", data_test)
print('===')
print("Label Train :")
print(y_train.value_counts())
print("\nLabel Test: ")
print(y_test.value_counts())
# Out:
# Total Data :  2400
# Data Latih :  2160
# Data Uji :  240
# ===
# Label Train :
# Negative    1081
# Positive    1079
# Name: label, dtype: int64
#
# Label Test:
# Positive    121
# Negative    119
# Name: label, dtype: int64

# %% [markdown]
# ### 7.2 Radom Forest Classifier

# %% [markdown]
# <i>Pada proses ini, data yang telah dibagi akan dimodeling dengan Random Forest Classifier untuk mendapatkan akurasi.

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()

rfc_fit = rfc.fit(X_train, y_train)
y_pred = rfc.predict(X_test)

predict = rfc.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

akurasi = accuracy_score(y_pred, y_test) * 100
akurasi_bulat = round(akurasi, 1)
print("Random Forest Classifier (Accuracy): ", akurasi_bulat, "%")
# Out:
# Random Forest Classifier (Accuracy):  87.1 %

# %% [markdown]
# ## 8. Evaluasi Performa (Confusion Matrix):

# %% [markdown]
# <i>Proses menampilkan Confusion Matrix. Confusion Matrix menyatakan jumlah data uji (test) yang benar dan salah diklasifikasi.

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report

#class report
classification_rep = classification_report(y_test, y_pred)

#conf matrix
cm = confusion_matrix(y_test, y_pred)

fig, ax = plt.subplots()
ConfusionMatrixDisplay(cm, display_labels=rfc.classes_).plot(ax=ax) 
plt.show(fig) 

print()
TP = cm[0, 0]
TN = cm[1, 1]
FP = cm[1, 0]
FN = cm[0, 1]
hitung_atas = TP + TN
hitung_bawah = TP + TN + FP + FN
Accuracy = (TP + TN) / (TP + TN + FP + FN)
#pembulatan
resultAccuracy = round(Accuracy, 3)
resultAccuracyPercent = round(Accuracy, 3)*100

equation = "(TP + TN) / (TP + TN + FP + FN) = Accuracy"
calculate = f"({TP} + {TN}) / ({TP} + {TN} + {FP} + {FN}) = {resultAccuracy}"
calculates = f"({hitung_atas}) / ({hitung_bawah}) = {resultAccuracy}"

hitung_true = TP+TN
hitung_false = FP+FN
df_cm = pd.DataFrame({
    "Value": [TP, TN, FP, FN],
    "Label": [
        "True Positive (TP)", "True Negative (TN)", "False Positive (FP)", "False Negative (FN)"
    ],
    "Klasifikasi Benar (TP+TN)": [hitung_true,"","",""],
    "Klasifikasi Salah (FP+FN)": [hitung_false,"","",""]
})

print("Rumus Akurasi:")
print(equation)
print()
print("Hitung Akurasi:")
print(calculate)
print(calculates)
print()
print("Classification Report:")
print(classification_rep)
print()
df_cm
# Out:
# Rumus Akurasi:
# (TP + TN) / (TP + TN + FP + FN) = Accuracy
#
# Hitung Akurasi:
# (109 + 100) / (109 + 100 + 21 + 10) = 0.871
# (209) / (240) = 0.871
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     Negative       0.84      0.92      0.88       119
#     Positive       0.91      0.83      0.87       121
#
#     accuracy                           0.87       240
#    macro avg       0.87      0.87      0.87       240
# weighted avg       0.87      0.87      0.87       240
#    Value                Label Klasifikasi Benar (TP+TN)  \
# 0    109   True Positive (TP)                       209
# 1    100   True Negative (TN)
# 2     21  False Positive (FP)
# 3     10  False Negative (FN)
#
#   Klasifikasi Salah (FP+FN)
# 0                        31
# 1
# 2
# 3

# %% [markdown]
# # Predictor

# %%
sample_review = "harga tiket murah"

# %%
sample_review1 = casefolding(sample_review)
sample_review2 = cleansing(sample_review1)    
sample_review3 = stemming(sample_review2)   
sample_review4 = convert_slangword(sample_review3)
sample_review5 = remove_stopword(sample_review4)
sample_review6 = remove_unwanted_words(sample_review5)
sample_review7 = remove_short_words(sample_review6)
sample_review8 = tokenizing(sample_review7)
temp = tf_idf_vector.transform(sample_review8)
predict = rfc.predict(temp)

# %%
predict
# Out:
# array(['Positive', 'Positive', 'Positive'], dtype=object)

# %%
import numpy as np
# Menghitung jumlah kemunculan kata yang diprediksi
jumlah_negative = np.count_nonzero(predict == 'Negative')
jumlah_positive = np.count_nonzero(predict == 'Positive')

print(jumlah_negative)
print(jumlah_positive)

if jumlah_negative >= jumlah_positive:
    sentiment_analysis = "Negative"
else:
    sentiment_analysis = "Positive"

print(sentiment_analysis)
# Out:
# 0
# 3
# Positive

# %% [markdown]
# # Save Pickle

# %%
import pickle
pickle.dump((rfc, tf_idf_vector), open('rfc_new.pkl','wb'))

# %% [markdown]
# <center>- Selesai. -</center>
